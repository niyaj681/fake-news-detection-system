# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FakeNewsNet.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...
# 1  People's Choice Awards 2018: The best red carp...
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...
# 3  Colombian singer Maluma sparks rumours of inap...
# 4  Gossip Girl 10 Years Later: How Upper East Sid...
#
#                                             news_url        source_domain  \
# 0  http://toofab.com/2017/05/08/real-housewives-a...           toofab.com
# 1  https://www.today.com/style/see-people-s-choic...        www.today.com
# 2  https://www.etonline.com/news/220806_sophia_bu...     www.etonline.com
# 3  https://www.dailymail.co.uk/news/article-33655...  www.dailymail.co.uk
# 4  https://www.zerchoo.com/entertainment/gossip-g...      www.zerchoo.com
#
#    tweet_num  real
# 0         42     1
# 1          0     1
# 2         63     1
# 3         20     1
# 4         38     1

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re

# %%
df.shape
# Out:
# (23196, 5)

# %%
df.isnull().sum()
# Out:
# title              0
# news_url         330
# source_domain    330
# tweet_num          0
# real               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 137

# %%
df.drop(['news_url', 'tweet_num'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                                title        source_domain  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...           toofab.com
# 1  People's Choice Awards 2018: The best red carp...        www.today.com
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...     www.etonline.com
# 3  Colombian singer Maluma sparks rumours of inap...  www.dailymail.co.uk
# 4  Gossip Girl 10 Years Later: How Upper East Sid...      www.zerchoo.com
#
#    real
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
df.dropna(axis = 0 , inplace = True)

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
stop_words = set(stopwords.words('english'))
len(stop_words)
# Out:
# 198

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
def remove_stopwords(text):
    words = word_tokenize(text)
    return ' '.join([word for word in words if word.lower() not in stop_words])

# %%
 import nltk
 nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['title'] = df['title'].apply(remove_stopwords)

# %%
df.head()
# Out:
#                                                title        source_domain  \
# 0  Kandi Burruss Explodes Rape Accusation 'Real H...           toofab.com
# 1  People 's Choice Awards 2018 : best red carpet...        www.today.com
# 2  Sophia Bush Sends Sweet Birthday Message 'One ...     www.etonline.com
# 3  Colombian singer Maluma sparks rumours inappro...  www.dailymail.co.uk
# 4  Gossip Girl 10 Years Later : Upper East Siders...      www.zerchoo.com
#
#    real
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
def clean_title(line):
    line = str(line)
    line = re.sub(r'[^a-zA-Z\s]', '', line)
    line = line.lower()
    return line

# %%
df['title'] = df['title'].apply(clean_title)

# %%
df['source'] = df['source_domain'].apply(clean_title)

# %%
df.head()
# Out:
#                                                title        source_domain  \
# 0  kandi burruss explodes rape accusation real ho...           toofab.com
# 1     people s choice awards   best red carpet looks        www.today.com
# 2  sophia bush sends sweet birthday message one t...     www.etonline.com
# 3  colombian singer maluma sparks rumours inappro...  www.dailymail.co.uk
# 4  gossip girl  years later  upper east siders sh...      www.zerchoo.com
#
#    real            source
# 0     1         toofabcom
# 1     1       wwwtodaycom
# 2     1    wwwetonlinecom
# 3     1  wwwdailymailcouk
# 4     1     wwwzerchoocom

# %%
df['text'] = df['title'] + ' ' + df['source_domain']

# %%
df.head()
# Out:
#                                                title        source_domain  \
# 0  kandi burruss explodes rape accusation real ho...           toofab.com
# 1     people s choice awards   best red carpet looks        www.today.com
# 2  sophia bush sends sweet birthday message one t...     www.etonline.com
# 3  colombian singer maluma sparks rumours inappro...  www.dailymail.co.uk
# 4  gossip girl  years later  upper east siders sh...      www.zerchoo.com
#
#    real            source                                               text
# 0     1         toofabcom  kandi burruss explodes rape accusation real ho...
# 1     1       wwwtodaycom  people s choice awards   best red carpet looks...
# 2     1    wwwetonlinecom  sophia bush sends sweet birthday message one t...
# 3     1  wwwdailymailcouk  colombian singer maluma sparks rumours inappro...
# 4     1     wwwzerchoocom  gossip girl  years later  upper east siders sh...

# %%
x = df['text'].values
y = df['real'].values

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X_train , X_test, y_train, y_test = train_test_split(x, y, test_size= 0.25, random_state= 42)

# %%
vectorizer = TfidfVectorizer()

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic = LogisticRegression()

# %%
logistic.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = logistic.predict(X_test)

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, pred)
# Out:
# 0.8600853590647616
